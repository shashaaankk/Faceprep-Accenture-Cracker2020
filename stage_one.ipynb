# %% [markdown]
# # #Move hyphen to the beginning
#
# Implement the following function: char* MoveHyphen(char str[], int n); The function accepts a string ‘str’ of length ‘n’, that contains alphabets and hyphens (-). Implement the function to move all hyphens (-) in the string to the front of the given string. Note: Return null if str is null.
#
# Input Format
# Given input is in given string
#
# Output Format
# Output is in string format
# Refer the sample output for formatting
#
# Sample Input:
# Move-Hyphens-to-Front
#
# Sample Output:
# ---MoveHyphenstoFront
#
# Explanation:
# The string “Move-Hyphens-to-Front” has 3 hyphens(-) which are moved to the front of the string thus output is “---MoveHyphenstoFront”.

# %%
def MoveHyphen(string,n):
    hypstring=""
    charstring=""
    for char in string:
      if char=='-':
        hypstring=hypstring+str(char)
      else:
        charstring=charstring+str(char) 
    print(hypstring+charstring) 
                  
string=input()
n=len(string)
MoveHyphen(string,n)

# %% [markdown]
# # Carry digit
#
#
# A carry is a digit that is transferred to left if sum of digits exceeds 9 while adding two numbers from right-to-left one digit at a time
# You are required to implement the following function.
# Int NumberOfCarries(int num1 , int num2);
# The functions accepts two numbers ‘num1’ and ‘num2’ as its arguments. You are required to calculate and return the total number of carries generated while adding digits of two numbers ‘num1’ and ‘ num2’.
# Assumption: num1, num2>=0
#
# Example:
# Input
# Num 1: 451
# Num 2: 349
# Output
# 2
# Explanation:
# Adding ‘num 1’ and ‘num 2’ right-to-left results in 2 carries since ( 1+9) is 10. 1 is carried and (5+4=1) is 10, again 1 is carried. Hence 2 is returned.
#
# Sample Input
# Num 1: 23
# Num 2: 563
# Sample Output
# 0

# %%
def NumOfCarries(num1,num2):
    c_count=0
    carry=0
    num1=int(num1)
    num2=int(num2)
    if (int(num1%10) + int(num2%10)>9):
        x=int(num1%10) + int(num2%10)
        carry=int((x/10)%10)
        c_count+=1
        if (carry+int((num1/10)%10) + int((num2/10)%10)>9):
            carry=0
            x=carry+int((num1/10)%10) + int((num2/10)%10)
            carry=int((x/10)%10)
            c_count+=1
        if (carry+int((num1/100)%10) + int((num2/100)%10)>9):
            carry=0
            x=carry+int((num1/10)%10) + int((num2/10)%10)
            carry=int((x/10)%10)
            c_count+=1
    print(c_count)
    
num1,num2=input().split()
NumOfCarries(num1,num2)

# %% [markdown]
# # Replace character
#
#
# You are given a function,
#
# Void *ReplaceCharacter(Char str[], int n, char ch1, char ch2);
#
# The function accepts a string ‘ str’ of length n and two characters ‘ch1’ and ‘ch2’ as its arguments . Implement the function to modify and return the string ‘ str’ in such a way that all occurrences of ‘ch1’ in original string are replaced by ‘ch2’ and all occurrences of ‘ch2’ in original string are replaced by ‘ch1’.
#
# Assumption: String Contains only lower-case alphabetical letters.
#
# Note:
#
# Return null if string is null.
# If both characters are not present in string or both of them are same , then return the string unchanged.
# Example:
#
# Input:
# Str: hello
# ch1:e
# ch2:o
# Output:
# holle
# Explanation:
#
# ‘e' in original string is replaced with ‘o’ and ‘o’ in original string is replaced with ‘e’, thus output is holle.

# %%
def replacechar(ipstr,ch1,ch2):
    opstr=""
    for ch in ipstr:
        if ch==ch1:
           ch=ch2
        elif ch==ch2:
           ch=ch1
        opstr=opstr+ch
    print(opstr)
    
    
ipstr,ch1,ch2=input().split()
replacechar(ipstr,ch1,ch2)

# %%
Second greatest element
Write a program to print the second greatest element in the given array. In case, if the second largest element is not present in the array, print "There is no second largest element" and if the size of the array is less than 2, print "Invalid Input".

Sample Input:

5

12 5 7 3 90

Sample Output:

12

# %%
if __name__ == '__main__':
    n = int(input())
    if n<2:
        print("Invalid Input")
    else:
        arr = list(map(int, input().split()))
        #x=max(arr)
        #while max(arr)==x:
        if(max(arr)):
            arr.remove(max(arr))
            print(max(arr))
        else:
            print("There is no second largest element")

# %%
Most occurring character
Write a program to find the most occurring character in the string.

sample Input:
Happy coding

Sample Output:
p

# %%
def most_frequent(ipstr):
    maxkey = ''
    maxvalue = 0
    count={}
    for char in ipstr:
        if char not in count:
           count[char]=1
        else:
          count[char]+=1 
    for char in ipstr:
        v = count[char]
        if v > maxvalue:
            maxvalue = v
            maxkey = char
    print(maxkey)

ip=input()
most_frequent(ip.lower())

# %% [markdown]
# # Find the Nth element
# Write a program to create a Singly Linked List and find the Nth element from the end of the list.
#
# Hint : Insertion at the beginning.
#
# Output:
#
# output consists of single line, print the element in the given position in a list, else print"No node found"
#
# Sample Input:
#
# 5
#
# 10 8 6 4 0
#
# 2
#
# Output:
#
# 8

# %%
def find_n(x,N):
  l=len(x)
  for i in range(len(x)):
        if i==N-1:
          print(x[i])
          break
  if(N>l):
     print("No node found")


n=int(input())          
x = list(map(int, input().rstrip().split()))
#print(x)
N=int(input())
find_n(x,N)

# %%
Integer Difference
Given an array arr and two integer value n and m as input, take the first element and find the difference between the first element and the integer value n. If the difference is less than m then increment that particular array element. Do this for all the element in an array and print the final modified array as output.

Sample Input:

5

2 1 4 5 7

3 2

Sample Output:

3 2 5 5 7

# %%
def func(arr,n,m):
  for i in range(len(arr)):
      if arr[i]-n < m:
         arr[i]+=1
      elif arr[i]-n >= m:
         arr[i]=arr[i]
      print(arr[i],end=" ")
  
num=int(input())
arr=list(map(int,input().rstrip().split()))
intn,intm = map(int,input().split())

func(arr,intn,intm)
